# %% [markdown]
# <a href="https://colab.research.google.com/github/Destian0870/PCVK_Ganjil2026/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39fabf2b-3860-4e8b-aaec-2078febe7c04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39fabf2b-3860-4e8b-aaec-2078febe7c04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np

img = cv.imread('KTP.png')

cv2_imshow(img)

print("Resolusi gambar: ", img.shape[1], " x ", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=332x211>
# Resolusi gambar:  332  x  211

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('KTP.png')
plt.imshow(img)
plt.show()

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img_gray = cv.imread('KTP.png', cv.IMREAD_GRAYSCALE)

plt.subplot(1, 2, 1)
plt.imshow(img_gray)
plt.title('Tanpa cmap')

plt.subplot(1, 2, 2)
plt.imshow(img_gray, cmap='gray')
plt.title('Dengan cmap')

plt.show()

# %%
plt.imshow(img_gray, cmap='magma')
plt.title("Colormap 'magma'")
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('KTP.png')

imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_output = cv.resize(imgRGB, (347, 229))
plt.imshow(img_output)

plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
imgFlip = cv.flip(img_output, 1)

plt.imshow(imgFlip)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8b7159d-f9be-4e1c-b91d-c98e385a0de6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8b7159d-f9be-4e1c-b91d-c98e385a0de6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv.imread('KTP.png')
imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_output = cv.resize(imgRGB, (347, 229))

# %%
imgFlip = cv.flip(img_output, 1)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.imshow(imgFlip)
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
black_img = np.zeros(shape=(530, 530, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(290, 0), pt2=(520, 130), color=(0, 0, 255), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(250, 250), pt2=(350, 350), color=(255, 0, 0), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(150, 150), radius=60, color=(0, 255, 0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400, 400), radius=50, color=(0, 255, 0), thickness=-1)
cv.line(black_img, pt1=(0, 0), pt2=(530, 530), color=(255, 255, 255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='PCVK is fun!',org=(10,500),fontFace=font,fontScale=2,
           color=(255,255,0),thickness=3,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(530, 530, 3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[150,350],[250,250],[450,350],[250,450]],dtype=np.int32)
vertices
# Out:
# array([[150, 350],
#        [250, 250],
#        [450, 350],
#        [250, 450]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[150, 350]],
#
#        [[250, 250]],
#
#        [[450, 350]],
#
#        [[250, 450]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(0,255,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Pertanyaan Praktikum

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import skimage.io

# %%
img_bgr = cv2.imread('KTP.png')
print("--- Jawaban 1 ---")
print("Nilai piksel koordinat (100, 100) BGR:", img_bgr[100, 100])
cv2_imshow(img_bgr)
plt.imshow(img_bgr)
plt.show()
# Out:
# --- Jawaban 1 ---
# Nilai piksel koordinat (100, 100) BGR: [159 198 252]
# <PIL.Image.Image image mode=RGB size=332x211>

# %% [markdown]
# - Mengapa Berbeda: OpenCV (cv2.imread) membaca citra dalam format warna BGR, sedangkan Matplotlib (plt.imshow) menggunakan format RGB
#
# - Pembuktian: Nilai piksel pada koordinat [100, 100] tercetak sebagai urutan BGR [B, G, R].

# %%
canvas_int16 = np.zeros(shape=(530, 530, 3), dtype=np.int16)
canvas_int32 = np.zeros(shape=(530, 530, 3), dtype=np.int32)

print("\n--- Jawaban 2 ---")
print(f"int16 -> dtype: {canvas_int16.dtype}, min: {canvas_int16.min()}, max: {canvas_int16.max()}, nbytes: {canvas_int16.nbytes} bytes")
print(f"int32 -> dtype: {canvas_int32.dtype}, min: {canvas_int32.min()}, max: {canvas_int32.max()}, nbytes: {canvas_int32.nbytes} bytes")
# Out:
# --- Jawaban 2 ---
# int16 -> dtype: int16, min: 0, max: 0, nbytes: 1685400 bytes
# int32 -> dtype: int32, min: 0, max: 0, nbytes: 3370800 bytes

# %% [markdown]
# - Perbandingan Properti:
# int16: dtype=int16, min=0, max=0, nbytes=1685400 bytes (1.68 MB).
# int32: dtype=int32, min=0, max=0, nbytes=3370800 bytes (3.37 MB).
#
# - Tampilan: Tampilannya sama saja (keduanya berupa kanvas hitam polos).
#
# - Ukuran Memori: Berbeda. Memori int32 dua kali lebih besar dibanding int16 karena tipe data int32 mengalokasikan 32 bit (4 byte) per elemen piksel, sedangkan int16 hanya mengalokasikan 16 bit (2 byte).

# %% [markdown]
# 3. - from google.colab.patches import cv2_imshow berfungsi untuk mengimpor fungsi tampilan pengganti khusus Google Colab.
#
#     - cv2.imshow() bawaan OpenCV tidak dapat dipakai di Colab karena fungsi tersebut mencoba membuka jendela GUI native sistem operasi yang menyebabkan crash pada lingkungan cloud notebook Colab.

# %%
img_skimage = skimage.io.imread('KTP.png')
img_converted = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

print("\n--- Jawaban 4 ---")
print("Nilai piksel (100,100) skimage:", img_skimage[100, 100])
print("Nilai piksel (100,100) cvtColor RGB:", img_converted[100, 100])
# Out:
# --- Jawaban 4 ---
# Nilai piksel (100,100) skimage: [252 198 159 255]
# Nilai piksel (100,100) cvtColor RGB: [252 198 159]

# %% [markdown]
# - Warna Sebenarnya: skimage.io.imread() membaca citra langsung dalam format RGB, begitu pula dengan cv2.cvtColor(img, cv2.COLOR_BGR2RGB). Keduanya menampilkan warna asli/sebenarnya.
#
# - Pembuktian: Nilai piksel keduanya pada koordinat yang sama identik (misalnya [R, G, B]), menandakan tidak ada kanal yang tertukar di antara kedua metode tersebut.

# %%
print("\n--- Jawaban 5 ---")
print("Ukuran piksel asli (img.shape):", img_bgr.shape)
fig = plt.figure(figsize=(10, 10))
plt.imshow(img_converted)
plt.show()
print("Ukuran piksel setelah figsize (img.shape):", img_bgr.shape)
# Out:
# --- Jawaban 5 ---
# Ukuran piksel asli (img.shape): (211, 332, 3)
# Ukuran piksel setelah figsize (img.shape): (211, 332, 3)

# %% [markdown]
# - Nilai img.shape: Tidak berubah.
#
# - Perbedaan:
#
#   - Mengubah ukuran citra (cv2.resize): Mengubah jumlah piksel/data matrik citra secara permanen, sehingga nilai img.shape berubah.
#
#   - Mengubah ukuran tampilan (figsize): Hanya mengubah skala visual penayangan gambar pada layar (plot), tanpa mengubah matriks dan jumlah piksel asli dari citra tersebut.

# %% [markdown]
# Tugas Praktikum

# %% [markdown]
# 1.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('KTP.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rb = img_rgb.copy()
img_rb[:, :, 1] = 0

# %%
img_gb = img_rgb.copy()
img_gb[:, :, 0] = 0

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rb)
plt.title('Kombinasi Merah-Biru')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_gb)
plt.title('Kombinasi Hijau-Biru')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# 2.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('KTP.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
flip_vert = cv2.flip(img_rgb, 0)
flip_horiz = cv2.flip(img_rgb, 1)
flip_both = cv2.flip(img_rgb, -1)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(flip_vert)
plt.title('Pencerminan Vertikal')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(flip_horiz)
plt.title('Pencerminan Horizontal')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(flip_both)
plt.title('Pencerminan Keduanya')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.

# %%
import cv2
import matplotlib.pyplot as plt

img_asli = cv2.imread('FotoKegiatan.jpeg')

img_draw = cv2.cvtColor(img_asli, cv2.COLOR_BGR2RGB)

height = img_draw.shape[0]
width = img_draw.shape[1]

cv2.rectangle(img_draw, pt1=(int(width * 0.50), int(height * 0.08)), pt2=(int(width * 0.93), int(height * 0.82)), color=(255, 0, 0), thickness=6)

cv2.circle(img_draw, center=(int(width * 0.38), int(height * 0.65)), radius=int(width * 0.15), color=(0, 255, 0), thickness=6)

font = cv2.FONT_HERSHEY_DUPLEX
cv2.putText(img_draw, text='Destian', org=(int(width * 0.05), int(height * 0.12)), fontFace=font, fontScale=2.5, color=(255, 255, 255), thickness=5, lineType=cv2.LINE_AA)

plt.figure(figsize=(6, 6))
plt.imshow(img_draw)
plt.title('Penerapan Shape & Text pada Foto Kegiatan')
plt.axis('off')
plt.show()

# %% [markdown]
# Tugas Praktikum-Analisa

# %% [markdown]
# Pertanyaan
#
# "Apakah ukuran (dimensi) citra FotoKegiatan.jpeg berubah setelah kanal warnanya dipisah menjadi kanal Red, Green, dan Blue (RGB)?"

# %%
import cv2

img = cv2.imread('FotoKegiatan.jpeg')

h, w, c = img.shape
b, g, r = cv2.split(img)

print(f"Dimensi Asli    : {h} x {w} pixels ({c} channels)")
print(f"Dimensi Kanal R : {r.shape[0]} x {r.shape[1]} pixels (1 channel)")
# Out:
# Dimensi Asli    : 1600 x 1265 pixels (3 channels)
# Dimensi Kanal R : 1600 x 1265 pixels (1 channel)

# %% [markdown]
# Jadi Pemisahan kanal warna (channel splitting) tidak mengubah resolusi (tinggi dan lebar) citra FotoKegiatan.jpeg. Karena Proses ini hanya memisahkan matriks 3 dimensi (RGB) menjadi 3 buah matriks 2 dimensi terpisah untuk masing-masing warna.

# %% [markdown]
# Tugas Praktikum-Aplikasi

# %% [markdown]
# Studi kasus 1

# %%
import cv2
import matplotlib.pyplot as plt

def tambah_label_adaptif(image_path, text="Dokumentasi PCVK - 2026"):

    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    h, w, _ = img_rgb.shape
    bar_height = h // 12

    cv2.rectangle(img_rgb, (0, h - bar_height), (w, h), (0, 0, 0), -1)

    font_scale = bar_height / 55.0
    thickness = max(1, int(bar_height / 30.0))
    text_x = int(w * 0.02)
    text_y = int(h - (bar_height * 0.35))

    cv2.putText(img_rgb, text, (text_x, text_y),
                cv2.FONT_HERSHEY_SIMPLEX, font_scale, (255, 255, 255), thickness, cv2.LINE_AA)

    return img_rgb

hasil_studi_1 = tambah_label_adaptif('FotoKegiatan.jpeg')

plt.figure(figsize=(6, 6))
plt.imshow(hasil_studi_1)
plt.title('Studi Kasus 1: Label Adaptif')
plt.axis('off')
plt.show()

# %% [markdown]
# Studi Kasus 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def buat_thumbnail_persegi(image_path, nama_toko="TOKO PCVK"):

    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    h, w, _ = img_rgb.shape

    max_side = int(max(h, w) * 1.25)

    kanvas = np.ones((max_side, max_side, 3), dtype=np.uint8) * 255

    thickness_bingkai = max(1, int(max_side / 300.0))
    cv2.rectangle(kanvas, (0, 0), (max_side-1, max_side-1), (0, 0, 0), thickness_bingkai)

    offset_y = (max_side - h) // 2
    offset_x = (max_side - w) // 2

    kanvas[offset_y:offset_y+h, offset_x:offset_x+w] = img_rgb

    font_scale = max_side / 900.0
    thickness = max(1, int(max_side / 450.0))
    text_y = int(offset_y / 1.8) if offset_y > 30 else int(max_side * 0.06)

    cv2.putText(kanvas, nama_toko, (int(max_side * 0.05), text_y),
                cv2.FONT_HERSHEY_SIMPLEX, font_scale, (30, 30, 30), thickness, cv2.LINE_AA)

    return kanvas

hasil_studi_2 = buat_thumbnail_persegi('FotoKegiatan.jpeg')

plt.figure(figsize=(6, 6))
plt.imshow(hasil_studi_2)
plt.title('Studi Kasus 2: Thumbnail 1:1')
plt.axis('off')
plt.show()
